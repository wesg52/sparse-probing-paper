# %%
import sys
import pickle
import os

import torch
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.getenv('SPARSE_PROBING_ROOT'))
from probing_datasets import wikidata
from config import ExperimentConfig, FeatureDatasetConfig
from load import *
from analysis.load_results import *
from analysis.plots.sparsity_probes import *

# %% [markdown]
# ## Load Results

# %%
dataset_property = "sex_or_gender"
dataset_size = 6000
dataset_property = "occupation"
dataset_size = 6000
# dataset_property = 'political_party'
# dataset_size = 3000
# dataset_property = 'is_alive'
# dataset_size = 6000
# dataset_property = 'occupation_athlete'
# dataset_size = 5000

model_sizes = ['6.9b']

# prefix = 'wikidata_full'
prefix = 'wikidata_sorted'

experiment_info = {
    'results_dir': os.getenv('RESULTS_DIR'),
    'experiment_name': f'wikidata/{dataset_property}',
    'dataset_name': f'{prefix}_{dataset_property}.pyth.128.{dataset_size}',
    'inner_loop': 'telescopic_sparsity_sweep',
}
all_results = []
for s in model_sizes:
    results_dict, config = load_probing_experiment_results(**experiment_info, model_name=f'pythia-{s}')

    flattened_results = {}
    for (feature, layer, aggregation, hook_loc), value in results_dict.items():
        if aggregation == 'max':
            for k in value.keys():
                flattened_results[(feature, layer, k)] = value[k]
    rdf = pd.DataFrame(flattened_results).T.rename_axis(index=['feature', 'layer', 'k']).sort_index()
    rdf.index = pd.MultiIndex.from_tuples(
        [(s, *i) for i in rdf.index.values],
        names=['model_size', 'feature', 'layer', 'k'])

    all_results.append(rdf)
rdf = pd.concat(all_results)
rdf.shape
# Out:
# (3360, 20)

# %%
# for any k
n_per_model = 5
cols = ['test_mcc', 'test_f1_score',]
all_pr_auc = []
for s in model_sizes:
    model_rdf = rdf.query(f'model_size=="{s}"').sort_values('test_mcc', ascending=False).head(n_per_model)[cols]
    all_pr_auc.append(model_rdf)
pd.concat(all_pr_auc)
# Out:
#                                                 test_mcc test_f1_score
# model_size feature                     layer k
# 6.9b       association football player 19    4  0.882738       0.90183
#                                              3  0.882738       0.90183
#                                              5   0.87913      0.899174
#                                              2  0.878739      0.898502
#                                              1  0.877478      0.898026

# %%
# for k=1
n_per_model = 5
cols = ['test_mcc', 'test_f1_score', 'coef']
all_pr_auc = []
for s in model_sizes:
    model_rdf = rdf.query(f'model_size=="{s}" and k==1').sort_values('test_mcc', ascending=False).head(n_per_model)[cols]
    all_pr_auc.append(model_rdf)
pd.concat(all_pr_auc)
# Out:
#                                                 test_mcc test_f1_score  \
# model_size feature                     layer k
# 6.9b       association football player 19    1  0.877478      0.898026
#                                        15    1  0.869818      0.891803
#                                        11    1  0.850729      0.876221
#            athlete                     9     1  0.807188      0.833631
#            association football player 21    1  0.806448       0.83304
#
#                                                         coef
# model_size feature                     layer k
# 6.9b       association football player 19    1   [13.818521]
#                                        15    1  [13.8263445]
#                                        11    1   [13.777381]
#            athlete                     9     1   [11.684192]
#            association football player 21    1   [12.206711]

# %% [markdown]
# ## Sparsity Curves

# %%
# for s in model_sizes:
#     plot_layer_metric_over_sparsity_per_feature(rdf.query(f'model_size=="{s}"').reset_index(level=0, drop=True), metric='test_mcc', n_cols=2)
#     plt.suptitle(f'pythia-{s}', y=1.0)

# %%
# for s in model_sizes:
#     plot_metric_over_sparsity_per_layer(rdf.query(f'model_size=="{s}"').reset_index(level=0, drop=True), metric='test_f1_score')
#     plt.suptitle(f'pythia-{s}', y=1.0)

# %% [markdown]
# ## Monosemantic Neurons

# %%
em_results = {}
for s in model_sizes:
    em_results[s] = {}
    em_path = os.path.join(os.environ['RESULTS_DIR'], experiment_info['experiment_name'], f'pythia-{s}', experiment_info['dataset_name'], 'enumerate_monosemantic')
    for file_name in os.listdir(em_path):
        if file_name == 'config.json':
            continue

        _, feature, _, _, _, layer, _ = file_name.split('.')
        d = pickle.load(open(os.path.join(em_path, file_name), 'rb'))
        scores = sorted([(k, v['test_mcc'], v['test_f1_score'], v['coef'].item()) for k, v in d.items()], key=lambda x: x[1], reverse=True)

        if feature not in em_results[s]:
            em_results[s][feature] = {}
        em_results[s][feature][int(layer)] = scores

# %%
# model top single neurons
num_top_neurons = 1
n_per_layer = 30
features = sorted(rdf.index.get_level_values(1).unique())
for s in model_sizes:
    print(f'pythia-{s}')
    for f in features:
        print(f'\t{f}')
        # NOTE: we are sorting by f1 score
        top_neurons = [(l,) + em_results[s][f][l][i] for i in range(n_per_layer) for l in em_results[s][f]]
        top_neurons = sorted(top_neurons, key=lambda x: x[3], reverse=True)[:num_top_neurons]
        for n in top_neurons:
            lix, nix, mcc, f1, coef = n
            # print(f'\t\t{lix}, {nix}: mcc={mcc:.3f}, f1={f1:.3f}, coef={coef:.3f}')
            print(f'\t\t({lix}, {nix}): mcc={mcc:.3f}, f1={f1:.3f}, coef={coef:.3f}')
# Out:
# pythia-6.9b
# 	actor
# 		(9, 4502): mcc=0.662, f1=0.714, coef=15.877
# 	association football player
# 		(19, 10761): mcc=0.886, f1=0.901, coef=19.048
# 	athlete
# 		(9, 12997): mcc=0.802, f1=0.832, coef=16.932
# 	journalist
# 		(9, 3974): mcc=0.577, f1=0.640, coef=12.740
# 	politician
# 		(11, 12520): mcc=0.533, f1=0.604, coef=11.011
# 	researcher
# 		(12, 11379): mcc=0.529, f1=0.597, coef=-14.224
# 	singer
# 		(23, 8865): mcc=0.718, f1=0.761, coef=13.583

# %%
# best neuron per feature per layer
num_top_neurons = 999
n_per_layer = 1
features = sorted(rdf.index.get_level_values(1).unique())
for s in model_sizes:
    print(f'\tpythia-{s}')
    for f in features:
        print(f'\t\t{f}')
        # NOTE: we are sorting by f1 score
        top_neurons = [(l,) + em_results[s][f][l][i] for i in range(n_per_layer) for l in em_results[s][f]]
        top_neurons = sorted(top_neurons, key=lambda x: x[3], reverse=True)[:num_top_neurons]
        for n in top_neurons:
            lix, nix, mcc, f1, coef = n
            # print(f'\t\t{lix}, {nix}: mcc={mcc:.3f}, f1={f1:.3f}, coef={coef:.3f}')
            print(f'pythia-{s},{experiment_info["dataset_name"]},{f},{lix},{nix},{mcc:.3f},{f1:.3f},{coef:.3f}')
        print()
# Out:
# 	pythia-6.9b
# 		actor
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,9,4502,0.662,0.714,15.877
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,11,12827,0.633,0.695,14.174
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,19,2285,0.604,0.671,15.233
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,8,2581,0.597,0.665,14.405
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,15,10563,0.599,0.664,13.258
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,10,7731,0.572,0.642,11.190
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,13,6293,0.567,0.640,12.322
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,14,11981,0.565,0.639,14.081
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,7,1655,0.559,0.634,13.420
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,23,14315,0.558,0.631,13.782
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,16,1333,0.550,0.624,11.132
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,6,11331,0.546,0.621,11.239
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,22,13464,0.526,0.604,11.317
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,17,15344,0.506,0.577,10.892
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,18,13581,0.485,0.569,9.945
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,25,13265,0.460,0.545,8.131
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,20,13728,0.454,0.543,8.552
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,27,7068,0.454,0.542,9.666
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,21,2473,0.445,0.534,8.606
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,29,8577,0.427,0.527,8.748
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,28,4976,0.426,0.526,9.592
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,12,5962,0.444,0.524,6.904
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,24,13744,0.431,0.514,8.739
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,26,12031,0.394,0.501,9.541
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,30,5833,0.379,0.490,8.994
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,31,7251,0.369,0.482,9.207
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,5,1999,0.303,0.410,6.315
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,2,607,0.136,0.318,-3.113
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,4,6513,0.129,0.313,5.189
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,3,2952,0.122,0.312,2.606
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,1,5526,0.114,0.308,3.774
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,0,4239,0.083,0.295,-1.746
#
# 		association football player
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,19,10761,0.886,0.901,19.048
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,15,2298,0.865,0.888,18.749
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,11,6071,0.842,0.870,19.073
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,21,5514,0.809,0.835,18.933
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,18,301,0.795,0.826,17.347
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,9,12997,0.781,0.817,17.730
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,16,652,0.789,0.815,18.395
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,13,15589,0.773,0.811,18.290
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,8,1677,0.775,0.806,16.444
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,20,2416,0.759,0.797,18.899
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,25,6617,0.746,0.790,17.069
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,14,3949,0.774,0.789,15.983
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,12,9624,0.755,0.788,16.579
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,7,687,0.734,0.777,16.844
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,22,12640,0.689,0.742,17.540
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,23,7745,0.688,0.727,14.415
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,26,9916,0.644,0.708,15.292
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,27,16087,0.653,0.707,14.080
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,17,12500,0.658,0.686,10.129
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,28,6566,0.597,0.664,13.442
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,29,8308,0.597,0.662,12.929
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,24,14510,0.614,0.660,12.736
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,31,2836,0.535,0.619,12.958
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,30,14335,0.534,0.617,11.106
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,6,16071,0.592,0.596,9.731
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,10,6321,0.485,0.580,12.549
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,3,1546,0.452,0.521,9.888
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,2,607,0.354,0.479,6.984
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,5,5727,0.371,0.478,7.184
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,1,4636,0.204,0.370,6.068
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,4,10435,0.168,0.345,3.073
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,17,14228,0.446,0.539,7.478
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,10,10723,0.482,0.538,8.755
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,22,10952,0.430,0.532,8.140
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,30,12878,0.426,0.531,7.087
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,16,464,0.521,0.530,5.678
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,28,5883,0.412,0.513,8.339
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,12,15733,0.477,0.510,7.407
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,8,10267,0.398,0.508,8.771
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,31,11882,0.391,0.445,3.802
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,5,1254,0.268,0.374,3.462
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,6,9791,0.227,0.370,4.451
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,4,14893,0.166,0.340,3.864
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,1,15886,0.138,0.327,-3.034
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,0,61,0.107,0.315,-2.814
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,3,2728,0.122,0.310,2.903
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,2,297,0.111,0.305,2.904

# %%
# top n neurons for each feature across all layers
num_top_neurons = 5
n_per_layer = 30
features = sorted(rdf.index.get_level_values(1).unique())
for s in model_sizes:
    # print(f'\tpythia-{s}')
    for f in features:
        # print(f'\t\t{f}')
        # NOTE: we are sorting by f1 score
        top_neurons = [(l,) + em_results[s][f][l][i] for i in range(n_per_layer) for l in em_results[s][f]]
        top_neurons = sorted(top_neurons, key=lambda x: x[3], reverse=True)[:num_top_neurons]
        for n in top_neurons:
            lix, nix, mcc, f1, coef = n
            # print(f'\t\t{lix}, {nix}: mcc={mcc:.3f}, f1={f1:.3f}, coef={coef:.3f}')
            print(f'pythia-{s},{experiment_info["dataset_name"]},{f},{lix},{nix},{mcc:.3f},{f1:.3f},{coef:.3f}')
        # print()
# Out:
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,9,4502,0.662,0.714,15.877
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,11,12827,0.633,0.695,14.174
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,9,4815,0.629,0.691,14.781
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,9,8260,0.619,0.683,13.714
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,actor,19,2285,0.604,0.671,15.233
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,19,10761,0.886,0.901,19.048
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,19,3514,0.878,0.899,18.969
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,15,2298,0.865,0.888,18.749
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,11,6071,0.842,0.870,19.073
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,association football player,21,5514,0.809,0.835,18.933
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,athlete,9,12997,0.802,0.832,16.932
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,athlete,11,6071,0.703,0.750,14.643
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,athlete,18,301,0.713,0.749,14.264
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,athlete,7,687,0.694,0.740,14.489
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,athlete,13,2842,0.656,0.701,12.727
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,journalist,9,3974,0.577,0.640,12.740
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,journalist,19,3401,0.536,0.600,10.501
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,journalist,17,2695,0.470,0.563,9.899
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,journalist,18,13608,0.492,0.560,9.110
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,journalist,11,2311,0.472,0.556,9.832
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,politician,11,12520,0.533,0.604,11.011
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,politician,17,6316,0.533,0.599,10.891
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,politician,9,613,0.543,0.599,11.007
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,politician,11,4111,0.525,0.597,9.594
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,politician,13,16089,0.511,0.592,10.772
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,researcher,12,11379,0.529,0.597,-14.224
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,researcher,11,1271,0.469,0.553,-6.648
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,researcher,10,9789,0.432,0.520,-8.451
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,researcher,11,3643,0.439,0.518,-12.688
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,researcher,9,2833,0.441,0.515,-15.301
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,23,8865,0.718,0.761,13.583
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,11,12667,0.727,0.759,13.752
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,18,7612,0.711,0.752,13.216
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,19,6141,0.668,0.718,13.197
# pythia-6.9b,wikidata_sorted_occupation.pyth.128.6000,singer,15,11317,0.658,0.695,12.797
